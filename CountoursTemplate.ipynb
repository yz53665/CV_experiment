# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('ExpPic/car/473.bmp')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
def showImg(imgs, x, y, dpi=100):
    plt.figure(figsize=(8,8), dpi=200)
    for index, i in enumerate(imgs):
        plt.subplot(x, y, index+1)
        plt.imshow(i, cmap='gray', filternorm=False)

# %%
plt.imshow(gray, cmap='gray')
print(gray.shape)
# Out:
# (240, 320)

# %%
dx = cv.Sobel(gray, cv.CV_32F, 0, 1, 1)
dy = cv.Sobel(gray, cv.CV_32F, 1, 0, 1)
dxy = np.sqrt(dx*dx + dy*dy)
dxy = np.uint0(dxy)
print(dx)
showImg([dx, dy, dxy], 1, 3, 200)
# Out:
# [[  0.   0.   0. ...   0.   0.   0.]
#  [148. 336. 666. ... 783. 687. 592.]
#  [ 56. 124. 235. ... 229. 209. 188.]
#  ...
#  [ -2.  -1.   1. ... -13.  -5.   2.]
#  [  6.  15.  25. ... -13.  -3.   0.]
#  [  0.   0.   0. ...   0.   0.   0.]]
